# %% [markdown]
# In this post, I will solve the energy balance equation for the flow of a single phase fluid in porous media. I don't use my work time to write in this blog. But this is an exception. The code is going to be used by one of iur students and it is a good idea to document it here.
#
# ## The physical system
# We have a L = 100 m x W = 20 m rectangular domain, that represent a cross section of a reservoir at 2000 m depth with a porousity of 35% and a permeability of 2 mDarcy, saturated with brine at 80 degree Celcius. Cold water at 25 degree Celsius is injected from the mid section on the left side of the domain, which in turn pushes brine out of the domain from the (mid section) on the right side. We assume that the top and bottom boundaries are closed to flow. But the temperature is fixed at 80 degree Celcius. We know that the density and viscosity of water changes with temperature, therefore we need a relation for them, which we can do by using the [CoolProp.jl](https://github.com/vimalaad/CoolProp.jl) package. Let's create a table of values:

# %%
# You can install CoolProp by:
# Pkg.clone("https://github.com/vimalaad/CoolProp.jl")
# Pkg.build("CoolProp")
using CoolProp, DataFrames, PyPlot, Polynomials, JFVM
# a table of density values
p_res = 80e5        # [Pa]
T_res = 80 + 273.15 # [K]
T_inj = 25 + 273.15 # [K]
T     = linspace(T_inj, T_res, 10)
rho_water = zeros(length(T))
mu_water  = zeros(length(T))
for i in eachindex(T)
    rho_water[i] = PropsSI("D", "T", T[i], "P", p_res, "water")           # [kg/m^3]
    mu_water[i]  = PropsSI("viscosity", "T", T[i], "P", p_res, "water")   # [Pa.s]
end
# display as a beautiful table with DataFrames
DataFrame(T_K = round(T, 2), μ_Pa_s = round(mu_water,6), ρ_kg_per_m3 = round(rho_water,2))
# Out:
# 10×3 DataFrames.DataFrame
# │ Row │ T_K    │ μ_Pa_s   │ ρ_kg_per_m3 │
# ├─────┼────────┼──────────┼─────────────┤
# │ 1   │ 298.15 │ 0.000889 │ 1000.58     │
# │ 2   │ 304.26 │ 0.000779 │ 998.79      │
# │ 3   │ 310.37 │ 0.000689 │ 996.7       │
# │ 4   │ 316.48 │ 0.000615 │ 994.33      │
# │ 5   │ 322.59 │ 0.000553 │ 991.7       │
# │ 6   │ 328.71 │ 0.000501 │ 988.84      │
# │ 7   │ 334.82 │ 0.000456 │ 985.76      │
# │ 8   │ 340.93 │ 0.000418 │ 982.47      │
# │ 9   │ 347.04 │ 0.000385 │ 978.98      │
# │ 10  │ 353.15 │ 0.000356 │ 975.3       │

# %% [markdown]
# It is possible to fit a polynomial function to the above table of data, using the [Polynomials.jl](https://github.com/JuliaMath/Polynomials.jl) package

# %%
mu_fit  = polyfit(T, mu_water, 2)
rho_fit = polyfit(T, rho_water, 2)
subplot(2,1,1)
scatter(T, mu_water, label = "μ data") 
plot(T, polyval(mu_fit, T))
xlabel("T [K]") 
ylabel("Viscosity [Pa.s]")
axis([minimum(T), maximum(T), minimum(mu_water), maximum(mu_water)])

subplot(2,1,2)
scatter(T, rho_water, label = "ρ data") 
plot(T, polyval(rho_fit, T))
xlabel("T [K]")
ylabel("Density [kg/m^3]");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff69cfa4c90>)

# %% [markdown]
# The above fit looks fine. Now we can go into the fun PDE part. The PDE's that we are going to solve read:
# $$\frac{\partial}{\partial t}\left(\varphi\rho\right)+\nabla.\left(\rho\mathbf{u}\right)=0,$$
# $$\mathbf{u}=-\frac{k}{\mu}\nabla p,$$
# $$\begin{multline*}
# \frac{\partial}{\partial t}\left(\varphi\rho c_{p,w}\left(T-T_{0}\right)+\left(1-\varphi\right)\rho_{s}c_{p,s}\left(T-T_{0}\right)\right)+\\
# +\nabla.\left(-\lambda\nabla T+\rho c_{p,w}\left(T-T_{0}\right)\mathbf{u}\right)=0
# \end{multline*}$$
#
# I'm not going to the details of the above equations, and I hope there is no mistakes since I wrote them from memory. The only change that make is that I replace T-T0 with the variable $\theta$. Let's define the domain and all the physical parameters.
#
# ## Physical parameters

# %%
T0    = 25.0 + 273.15  # [K] reference temperature
L     = 100            # [m]
W     = 20             # [m]
poros = 0.35           # [-]
perm  = 0.002e-12      # Darcy
T_inj = 25 + 273.15    # [K]
theta_inj = T_inj - T0 # [K]
T_res = 80 + 273.15    # [K]
theta_res = T_res - T0 # [K]
u_inj = 1.0/(3600*24)  # [m/s]
p_res = 200e5          # [Pa]
λ_water  = PropsSI("conductivity", "T", T_res, "P", p_res, "water") # W/m/K
λ_rock   = 0.16        # [W/m/K] rock conductivity (for sandstone from my thesis)
λ_eff    = λ_water^poros*λ_rock^(1-poros) # effective conductivity
cp_water = PropsSI("CPMASS", "T", T_res, "P", p_res, "water") # J/kg/K
cp_rock  = 837.0       # [J/kg/K] rock heat capacity (for sandstone)
rho_rock = 2650.0      # [kg/m^3] rock density (for sandstone)
# Out:
# 2650.0

# %% [markdown]
# ## Define the domain and its boundaries

# %%
Nx  = 100
Ny  = 20
left_range  = 9:11
right_range = 9:11
m   = createMesh2D(Nx, Ny, L, W)  # 2D Cartesian grid
BCp = createBC(m)                 # pressure boundary
BCp.left.a[left_range]  = perm/polyval(mu_fit, T_inj)
BCp.left.b[left_range]  = 0.0
BCp.left.c[left_range]  = -u_inj
BCp.right.a[right_range] = 0.0
BCp.right.b[right_range] = 1.0
BCp.right.c[right_range] = p_res

BCt = createBC(m)                 # temperature boundary
# Danckwertz with assumptions (density of water is almost constant)
rho_water_inj  = polyval(rho_fit, T_inj)
BCt.left.a[left_range]  = λ_eff
BCt.left.b[left_range]  = -rho_water_inj*cp_water*u_inj
BCt.left.c[left_range]  = -rho_water_inj*cp_water*u_inj*theta_inj;

# %% [markdown]
# ## Initial conditions

# %%
theta_init = createCellVariable(m, theta_res, BCt)
theta_val  = createCellVariable(m, theta_res, BCt)
p_init     = createCellVariable(m, theta_res, BCp)
p_val      = createCellVariable(m, theta_res, BCp)
rho_init   = createCellVariable(m, 
    polyval(rho_fit, theta_init.value+T0))
rho_val    = copyCell(rho_init)
mu_init    = createCellVariable(m, 
    polyval(mu_fit, theta_init.value+T0))
mu_val     = copyCell(mu_init);

# %% [markdown]
# ## Solver settings and discretization

# %%
dt         = 10*(L/Nx)/(u_inj/poros)   # [s] time step
final_time = Nx*dt                # [s], eq. to 1 pore volumes

# discretization
M_BCp, RHS_BCp = boundaryConditionTerm(BCp)
M_BCt, RHS_BCt = boundaryConditionTerm(BCt)
M_conductivity = diffusionTerm(-harmonicMean(
        createCellVariable(m, λ_eff)));

# %% [markdown]
# ## Solver loop

# %%
for t in dt:dt:final_time
    
    for i in 1:3 # internal loop
        # solve pressure equation
        RHS_ddt_p   = constantSourceTerm(poros/dt*(rho_val - rho_init))
        water_mobil = harmonicMean(perm*(rho_val./mu_val))
        M_diff_p    = diffusionTerm(-water_mobil)
        p_val       = solveLinearPDE(m, M_diff_p + M_BCp,
            RHS_BCp - RHS_ddt_p)
        
        # velocity vector
        u = -water_mobil.*gradientTerm(p_val)
        
        # solve heat equation
        α                  = poros*rho_val*cp_water+(1-poros)*
            rho_rock*cp_rock
        M_trans, RHS_trans = transientTerm(theta_init, dt, α)
        M_conv             = convectionUpwindTerm(cp_water*u)
        theta_val          = solveLinearPDE(m, 
            M_BCt + M_conv + M_trans + M_conductivity,
            RHS_BCt + RHS_trans)
        
        # update density and viscosity values
        rho_val.value[:] = polyval(rho_fit, theta_val.value + T0)
        mu_val.value[:]  = polyval(mu_fit, theta_val.value + T0)
    end # end of inner loop
    
    rho_init   = copyCell(rho_val)
    p_init     = copyCell(p_val) # not necessary
    theta_init = copyCell(theta_val)
end

# %%
visualizeCells(theta_val+T0)
colorbar()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff69cb94d50>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x7ff69c8a3dd0>

# %%
visualizeCells(p_val)
colorbar()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7ff69d87a350>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x7ff69c5fdd10>

# %%
p_val.value
# Out:
# 102×22 Array{Float64,2}:
#  0.0        6.75522e7  6.76852e7  …  6.68814e7  6.67677e7  0.0
#  6.75522e7  6.75522e7  6.76852e7     6.68814e7  6.67677e7  6.67677e7
#  6.74195e7  6.74195e7  6.75445e7     6.67631e7  6.66547e7  6.66547e7
#  6.71622e7  6.71622e7  6.72733e7     6.65329e7  6.64339e7  6.64339e7
#  6.67941e7  6.67941e7  6.68883e7     6.6202e7   6.61149e7  6.61149e7
#  6.63324e7  6.63324e7  6.64092e7  …  6.57841e7  6.57099e7  6.57099e7
#  6.57946e7  6.57946e7  6.58553e7     6.52936e7  6.52319e7  6.52319e7
#  6.51969e7  6.51969e7  6.52438e7     6.47441e7  6.46937e7  6.46937e7
#  6.45532e7  6.45532e7  6.45889e7     6.41474e7  6.41067e7  6.41067e7
#  6.38752e7  6.38752e7  6.39019e7     6.35137e7  6.34811e7  6.34811e7
#  6.31717e7  6.31717e7  6.31917e7  …  6.28512e7  6.2825e7   6.2825e7
#  6.24499e7  6.24499e7  6.24649e7     6.21664e7  6.21453e7  6.21453e7
#  6.17151e7  6.17151e7  6.17264e7     6.14646e7  6.14474e7  6.14474e7
#  ⋮                                ⋱             ⋮
#  2.68747e7  2.68747e7  2.68691e7  …  2.69839e7  2.69916e7  2.69916e7
#  2.65711e7  2.65711e7  2.65633e7     2.66961e7  2.67061e7  2.67061e7
#  2.62754e7  2.62754e7  2.62646e7     2.64178e7  2.64306e7  2.64306e7
#  2.59903e7  2.59903e7  2.59758e7     2.61516e7  2.61679e7  2.61679e7
#  2.57198e7  2.57198e7  2.57005e7     2.5901e7   2.59214e7  2.59214e7
#  2.54686e7  2.54686e7  2.54434e7  …  2.56702e7  2.56954e7  2.56954e7
#  2.52426e7  2.52426e7  2.52106e7     2.54641e7  2.54947e7  2.54947e7
#  2.50485e7  2.50485e7  2.50092e7     2.52885e7  2.53246e7  2.53246e7
#  2.48939e7  2.48939e7  2.48474e7     2.51494e7  2.51907e7  2.51907e7
#  2.47857e7  2.47857e7  2.47333e7     2.50527e7  2.50979e7  2.50979e7
#  2.473e7    2.473e7    2.46742e7  …  2.5003e7   2.50505e7  2.50505e7
#  0.0        2.473e7    2.46742e7     2.5003e7   2.50505e7  0.0
